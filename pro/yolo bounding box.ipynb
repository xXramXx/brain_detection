# %%
! pip3 install pyyaml ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#! python3 -m pip install ultralytics
#sudo pip3 install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import torch
from IPython.display import Image
from matplotlib import pyplot as plt
import numpy as np
import cv2
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_13739/3902477109.py in <module>
#       4 import numpy as np
#       5 import cv2
# ----> 6 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/ram/.cache/torch/hub/ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_21630/3267363982.py in <module>
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
#
# /media/ram/ubuntuspace/Exprement/saturn/pro/brain_mri_process/tf.13/lib/python3.7/site-packages/torch/hub.py in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     540                                            verbose=verbose, skip_validation=skip_validation)
#     541
# --> 542     model = _load_local(repo_or_dir, model, *args, **kwargs)
#     543     return model
#     544
#
# /media/ram/ubuntuspace/Exprement/saturn/pro/brain_mri_process/tf.13/lib/python3.7/site-packages/torch/hub.py in _load_local(hubconf_dir, model, *args, **kwargs)
#     570
# ...

# %%
! dir
# Out:
# bin	      my_figure.png	     tumor_detection_P2.ipynb
# brain_mri.py  new_mri_det_1.h5	     tumor_detection_svm.ipynb
# img	      new_mri_det_rf_1.h5    yolo\ bounding\ box.ipynb
# lib	      pyvenv.cfg	     yolov5
# main.py       tf.13		     yolov5s.pt
# mri_calss.h5  trainng_box.ipynb
# mri_det.h5    tumor_detection.ipynb

# %%
! cd yolov5/data

# %%
img=cv2.imread("/media/ram/ubuntuspace/Exprement/saturn/pro/brain_mri_process/yolov5/data/images/image(2).jpg")

# %%
img.shape
# Out:
# (641, 557, 3)

# %%
# !cd yolov5 && python train.py --img 641 --batch 10 --epochs 50 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=10, imgsz=641, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.7.16 torch-1.13.1+cu117 CPU
#
# ...

# %%
# !cd yolov5 && python val.py --weight ./yolov5/runs/train/exp2/weights/best.pt --data ./yolov5/runs/train/exp2/my_config.yaml
# Out:
# /bin/bash: line 1: python: command not found

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/ram/.cache/torch/hub/master.zip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in <module>
#      28 try:
# ---> 29     import ultralytics
#      30
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_13739/2904589513.py in <module>
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/ram/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-4 Python-3.7.16 torch-1.13.1+cu117 CPU
# requirements: /home/ram/.cache/torch/hub/requirements.txt not found, check failed.
# Fusing layers...
# Model summary: 157 layers, 7053277 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
model.conf=0.60

# %%
# %matplotlib inline 
results = model("/media/ram/ubuntuspace/Exprement/saturn/pro/brain_mri_process/yolov5/data/images/image(28).jpg")
plt.imshow(np.squeeze(results.render()))
plt.show()
